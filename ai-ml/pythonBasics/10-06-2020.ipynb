# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# plots using
# - Pandas
# - Matplotlib
# - seaborn

# %%
tips['total_bill'].hist()

# %%
plt.hist(tips['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <a list of 10 Patch objects>)

# %%
tips['tip'].hist()

# %%
plt.hist(tips['tip'])
# Out:
# (array([41., 79., 66., 27., 19.,  5.,  4.,  1.,  1.,  1.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(tips['total_bill'])

# %%
sns.relplot("total_bill","tip",data=tips,hue='smoker')

# %%
sns.relplot("total_bill","tip",data=tips,hue='smoker',col='sex')

# %%
sns.relplot("total_bill","tip",data=tips,hue='smoker',style='smoker')

# %%
sns.__version__
# Out:
# '0.9.0'

# %%
sns.scatterplot("total_bill","tip",data=tips)

# %% [markdown]
# ### categorical plots:

# %%
sns.catplot("day",'tip',data=tips)

# %%
sns.catplot("day",'total_bill',data=tips)

# %%
sns.catplot("time",'total_bill',data=tips,kind='swarm')

# %%
sns.catplot("time",'total_bill',data=tips,kind='swarm',hue='smoker',col='sex')

# %%
sns.catplot("day","total_bill",data=tips,kind='box')

# %%
sns.catplot("day","total_bill",data=tips,kind='box',hue='sex')

# %%
sns.catplot("day",data=tips,kind='count',hue='smoker')

# %%
sns.catplot("day",data=tips,kind='count',hue='smoker')

# %%
sns.boxplot(y=tips['tip'])

# %%
sns.countplot(tips['day'])

# %%
sns.distplot(tips['tip'])

# %%
sns.jointplot('total_bill','tip',data=tips)

# %%
sns.jointplot('total_bill','tip',data=tips,kind='kde')

# %%
sns.regplot("tip","total_bill",data=tips)

# %%
## pairwise plot for numerical values:

ty=tips.columns[tips.dtypes!='category']
val=1
for i in range(len(ty)):
    for j in range(len(ty)):
        plt.subplot(3,3,val)
        plt.scatter(tips[ty[i]],tips[ty[j]])
        plt.title(ty[i]+' vs ' + ty[j])
        val+=1
