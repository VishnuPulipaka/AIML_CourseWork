# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# creating a family column
df['Family']=df['SibSp']+df['Parch']
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Family
# 0      0  A/5 21171   7.2500   NaN        S       1
# 1      0   PC 17599  71.2833   C85        C       1

# %%
df.Family.describe()
# Out:
# count    891.000000
# mean       0.904602
# std        1.613459
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max       10.000000
# Name: Family, dtype: float64

# %%
dfn=df.drop(columns=['SibSp','Parch'])
dfn
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
dfn.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
## dividing fare into categories
dfn['Fare_Category']=pd.cut(dfn.Fare,bins=[0.000000,7.910400,14.454200,31.000000,512.329200],
                          labels=['Low','mid','mid-high','high'])
dfn.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# ...

# %%
# Comparimg the fare with category
dfn[['Fare','Fare_Category']]
# Out:
#         Fare Fare_Category
# 0     7.2500           Low
# 1    71.2833          high
# 2     7.9250           mid
# 3    53.1000          high
# 4     8.0500           mid
# ..       ...           ...
# 886  13.0000           mid
# 887  30.0000      mid-high
# 888  23.4500      mid-high
# 889  30.0000      mid-high
# 890   7.7500           Low
#
# [891 rows x 2 columns]

# %%
# Visaulise the fare data
sns.countplot(x='Fare_Category',data=dfn)

# %% [markdown]
# # Observation:
# - categories have NEARLY equal distribution
# - middles classes dominate

# %%
# survival based on category
sns.countplot(x='Fare_Category',hue='Survived',data=dfn)

# %% [markdown]
# ### Observation:
# - higher fare passengers have survived more

# %%
#Embarked: Port --> from where the passenger had noarded the shop
df.Embarked.value_counts(normalize=True)
# Out:
# S    0.724409
# C    0.188976
# Q    0.086614
# Name: Embarked, dtype: float64

# %%
## Visualising the Port column
sns.countplot(x='Embarked',data=dfn)

# %%
# visualising port vs survival

p=sns.countplot(x="Embarked",hue="Survived",data=dfn)
p.set_xticklabels(['Southampton','Cherbourg','Queenstown'])
# Out:
# [Text(0, 0, 'Southampton'), Text(0, 0, 'Cherbourg'), Text(0, 0, 'Queenstown')]

# %% [markdown]
# # Imputing with missing values:

# %%
df.isnull().mean().sort_values(ascending=False)
# Out:
# Cabin          0.771044
# Age            0.198653
# Embarked       0.002245
# Family         0.000000
# Fare           0.000000
# Ticket         0.000000
# Parch          0.000000
# SibSp          0.000000
# Sex            0.000000
# Name           0.000000
# Pclass         0.000000
# Survived       0.000000
# PassengerId    0.000000
# dtype: float64

# %%
## Cabin --> 77% missing values, make new category as 'New'
dfn.Cabin.fillna('NA',inplace=True)

# %%
dfn.Cabin.isnull().sum()
# Out:
# 0

# %%
dfn.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# Replacing missing values in Age with median
dfn.Age.fillna(df.Age.median(),inplace=True)
dfn.Age.isnull().sum()
# Out:
# 0

# %%
## Imputing Embarked column:
dfn.Embarked.fillna(df.Embarked.mode()[0],inplace=True)
dfn.Embarked.isnull().sum()
# Out:
# 0

# %%
# Imputing the Fare category column
dfn.Fare_Category.isnull().sum()
# Out:
# 15

# %%
dfn.Fare_Category.fillna(dfn.Fare_Category.mode()[0],inplace=True)
dfn.Fare_Category.isnull().sum()
# Out:
# 0

# %%
dfn.isnull().mean()
# Out:
# PassengerId      0.0
# Survived         0.0
# Pclass           0.0
# Name             0.0
# Sex              0.0
# Age              0.0
# Ticket           0.0
# Fare             0.0
# Cabin            0.0
# Embarked         0.0
# Family           0.0
# Fare_Category    0.0
# dtype: float64

# %%
# MAKE AGE RANGE
dfn["Age-Range"]=pd.cut(dfn.Age,[0,10,20,30,40,60,80])
dfn[["Age","Age-Range"]].head()
dfn[dfn["Age"]==28]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 23            24         1       1              Sloper, Mr. William Thompson
# 26            27         0       3                   Emir, Mr. Farred Chehab
# ..           ...       ...     ...                                       ...
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 874          875         1       2     Abelson, Mrs. Samuel (Hannah Wizosky)
# 878          879         0       3                        Laleff, Mr. Kristo
# 883          884         0       2             Banfield, Mr. Frederick James
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
#Encoding of Categorical Variables/Columns
dummy_set=pd.get_dummies(dfn.Fare_Category,drop_first=True)
dummy_set
# Out:
# Fare_Category  mid  mid-high  high
# 0                0         0     0
# 1                0         0     1
# 2                1         0     0
# 3                0         0     1
# 4                1         0     0
# ..             ...       ...   ...
# 886              1         0     0
# 887              0         1     0
# 888              0         1     0
# 889              0         1     0
# 890              0         0     0
#
# [891 rows x 3 columns]

# %%
dfn=pd.concat([dfn,dummy_set],axis=1)

# %%
dfn=pd.concat([dfn,pd.get_dummies(dfn.Cabin,prefix='Cabin',drop_first=True),
               pd.get_dummies(dfn.Embarked,prefix='emb',drop_first=True),
               pd.get_dummies(dfn.Fare_Category,prefix='Fare',drop_first=True),
               pd.get_dummies(dfn['Age-Range'],drop_first=True)],axis=1)

# %%
dfn
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
# Encoding the sex column
from sklearn.preprocessing import LabelEncoder
dfn['Sex']=LabelEncoder().fit_transform(dfn.Sex)
dfn.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  \
# 0                            Braund, Mr. Owen Harris    1  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2                             Heikkinen, Miss. Laina    0  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4                           Allen, Mr. William Henry    1  35.0
#
#              Ticket     Fare Cabin Embarked  ...  emb_Q emb_S Fare_mid  \
# 0         A/5 21171   7.2500    NA        S  ...      0     1        0
# 1          PC 17599  71.2833   C85        C  ...      0     0        0
# 2  STON/O2. 3101282   7.9250    NA        S  ...      0     1        1
# 3            113803  53.1000  C123        S  ...      0     1        0
# ...

# %%
# Drop the unnecessary columns
dfn.drop(['PassengerId','Name','Age','Ticket','Fare','Embarked','Fare_Category','Cabin','Age-Range']
         ,axis=1,inplace=True)
dfn.shape
# Out:
# (891, 164)

# %%
# Separating the Input and Output Data,dropping the 'Survived' column
X=dfn.drop('Survived',axis=1)
X.shape
# Out:
# (891, 163)

# %%
y=dfn.iloc[:,0]
y.shape
# Out:
# (891,)

# %% [markdown]
# ## input and output into training data and testing data
# ###### Training--> on training data
# ###### Testing --> performance check
# ###### 891 --> out of 891,75% of 891 rows will be in training ,rest in testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (668, 163)
# (223, 163)
# (668,)
# (223,)

# %%
pd.set_option('display.max_columns',None)
X_test.head(5)
# Out:
#      Pclass  Sex  Family  mid  mid-high  high  Cabin_A14  Cabin_A16  \
# 862       1    0       0    0         1     0          0          0
# 223       3    1       0    0         0     0          0          0
# 84        2    0       0    1         0     0          0          0
# 680       3    0       0    1         0     0          0          0
# 535       2    0       2    0         1     0          0          0
#
#      Cabin_A19  Cabin_A20  Cabin_A23  Cabin_A24  Cabin_A26  Cabin_A31  \
# 862          0          0          0          0          0          0
# 223          0          0          0          0          0          0
# 84           0          0          0          0          0          0
# 680          0          0          0          0          0          0
# 535          0          0          0          0          0          0
#
#      Cabin_A32  Cabin_A34  Cabin_A36  Cabin_A5  Cabin_A6  Cabin_A7  \
# ...

# %% [markdown]
# # 20-06-2020

# %%
from sklearn.linear_model import LogisticRegression
log_reg=LogisticRegression() #creating an object

# %%
# we have to apply this object(log_reg) to the training data
log_reg.fit(X_train,y_train) # fit method, we train the model
# Out:
# C:\Users\vishn\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# Instead of directly prediciting on test data, checking on traning data itself

# %%
#predicting on the training data:
y_train_pred=log_reg.predict(X_train)

# %%
# comparing y_Train and y_train_red
y_train==y_train_pred
# Out:
# 35      True
# 46      True
# 453     True
# 291     True
# 748     True
#        ...
# 715     True
# 767    False
# 72      True
# 235     True
# 37      True
# Name: Survived, Length: 668, dtype: bool

# %%
## accuracy score -->metric
from sklearn.metrics import accuracy_score
accuracy_score(y_train,y_train_pred)
# Out:
# 0.8458083832335329

# %%
y_test_p=log_reg.predict(X_test)
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
y_test==y_test_p
# Out:
# 862     True
# 223     True
# 84      True
# 680    False
# 535     True
#        ...
# 506     True
# 467     True
# 740    False
# 354     True
# 449    False
# Name: Survived, Length: 223, dtype: bool
