# %% [markdown]
# # CSE -221710302064 -Vishnu Pulipaka

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the dataset from the below path:
# https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/cities.csv

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/cities.csv")
df.head(2)
# Out:
#   name_of_city  state_code   state_name  dist_code  population_total  \
# 0      Abohar            3       PUNJAB          9            145238
# 1    Achalpur           27  MAHARASHTRA          7            112293
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# 1                 6186                   5624  ...             43086
#
#    sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 0        890              848                          79.86
# 1        928              909                          91.99
#
#    effective_literacy_rate_male  effective_literacy_rate_female  \
# 0                         85.49                           73.59
# ...

# %% [markdown]
# a. Analyze the  top 5 cities with highest number of female graduates
# b. Find the 5 cities with lowest number of female graduates and concatenate the two dataframes of top 5 cities with  bottom 5 cities
# c. Display only the rows which belong to Kerala, Bihar and Maharashtra.
# d. Find the  top 10 cities with highest total graduation rate
# e. Calculate the average child sex ratio of the Kerala State.

# %% [markdown]
# # a. Analyze the  top 5 cities with highest number of female graduates

# %%
fem_grad=df.nlargest(5,"female_graduates")
fem_grad
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 141              Delhi            7    NCT OF DELHI         99
# 185     Greater Mumbai           27     MAHARASHTRA         99
# 72            Bengaluru          29       KARNATAKA         18
# 184  Greater Hyderabad           28  ANDHRA PRADESH         99
# 119            Chennai           33      TAMIL NADU          2
#
#      population_total  population_male  population_female  \
# 141          11007835          5871362            5136473
# 185          12478447          6736815            5741632
# 72            8425970          4401299            4024671
# 184           6809970          3500802            3309168
# 119           4681087          2357633            2323454
#
#      0-6_population_total  0-6_population_male  0-6_population_female  ...  \
# 141               1209275               647938                 561337  ...
# 185               1139146               599007                 540139  ...
# ...

# %% [markdown]
# # b. Find the 5 cities with lowest number of female graduates and concatenate the two dataframes of top 5 cities with  bottom 5 cities

# %%
fem_low=df.nsmallest(5,"female_graduates").sort_values("female_graduates",ascending=False)
fem_low
# Out:
#     name_of_city  state_code      state_name  dist_code  population_total  \
# 323  Mustafabad            7    NCT OF DELHI          3            127012
# 374   Pithampur           23  MADHYA PRADESH         21            126099
# 234     Jamuria           19     WEST BENGAL          9            144971
# 39       Bagaha           10           BIHAR          1            113012
# 131     Dabgram           19     WEST BENGAL          2            118464
#
#      population_male  population_female  0-6_population_total  \
# 323            66754              60258                 19370
# 374            70577              55522                 20438
# 234            75574              69397                 17556
# 39             59946              53066                 19070
# 131            60708              57756                 14472
#
#      0-6_population_male  0-6_population_female  ...  literates_female  \
# 323                10176                   9194  ...             34201
# ...

# %%
b=pd.concat([fem_grad,fem_low],axis=0)
b
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 141              Delhi            7    NCT OF DELHI         99
# 185     Greater Mumbai           27     MAHARASHTRA         99
# 72            Bengaluru          29       KARNATAKA         18
# 184  Greater Hyderabad           28  ANDHRA PRADESH         99
# 119            Chennai           33      TAMIL NADU          2
# 323         Mustafabad            7    NCT OF DELHI          3
# 374          Pithampur           23  MADHYA PRADESH         21
# 234            Jamuria           19     WEST BENGAL          9
# 39              Bagaha           10           BIHAR          1
# 131            Dabgram           19     WEST BENGAL          2
#
#      population_total  population_male  population_female  \
# 141          11007835          5871362            5136473
# 185          12478447          6736815            5741632
# 72            8425970          4401299            4024671
# ...

# %%
df.state_name.unique()
# Out:
# array(['PUNJAB', 'MAHARASHTRA', 'ANDHRA PRADESH', 'JHARKHAND', 'TRIPURA',
#        'UTTAR PRADESH', 'GUJARAT', 'MIZORAM', 'RAJASTHAN', 'TAMIL NADU',
#        'KERALA', 'HARYANA', 'CHHATTISGARH', 'JAMMU & KASHMIR', 'BIHAR',
#        'WEST BENGAL', 'KARNATAKA', 'ORISSA', 'MADHYA PRADESH',
#        'NCT OF DELHI', 'CHANDIGARH', 'UTTARAKHAND', 'ASSAM', 'NAGALAND',
#        'MANIPUR ', 'PUDUCHERRY', 'ANDAMAN & NICOBAR ISLANDS', 'MEGHALAYA',
#        'HIMACHAL PRADESH'], dtype=object)

# %% [markdown]
# # c. Display only the rows which belong to Kerala, Bihar and Maharashtra.

# %%
df[(df.state_name=='KERALA')|(df.state_name=='BIHAR')|(df.state_name=='MAHARASHTRA')]
# Out:
#           name_of_city  state_code   state_name  dist_code  population_total  \
# 1            Achalpur           27  MAHARASHTRA          7            112293
# 8          Ahmadnagar           27  MAHARASHTRA         26            350905
# 12              Akola           27  MAHARASHTRA          5            427146
# 14          Alappuzha           32       KERALA         11            174164
# 20          Ambarnath           27  MAHARASHTRA         21            254003
# ..                 ...         ...          ...        ...               ...
# 472             Udgir           27  MAHARASHTRA         28            104063
# 475        Ulhasnagar           27  MAHARASHTRA         21            506937
# 482  Vasai Virar City           27  MAHARASHTRA         21           1221233
# 490            Wardha           27  MAHARASHTRA          8            105543
# 492          Yavatmal           27  MAHARASHTRA         14            116714
#
# ...

# %% [markdown]
# # d. Find the  top 10 cities with highest total graduation rate

# %%
citi10=df.nlargest(10,"total_graduates")
citi10
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 141              Delhi            7    NCT OF DELHI         99
# 185     Greater Mumbai           27     MAHARASHTRA         99
# 72            Bengaluru          29       KARNATAKA         18
# 184  Greater Hyderabad           28  ANDHRA PRADESH         99
# 119            Chennai           33      TAMIL NADU          2
# 274            Kolkata           19     WEST BENGAL         16
# 7            Ahmadabad           24         GUJARAT          7
# 380               Pune           27     MAHARASHTRA         25
# 288            Lucknow            9   UTTAR PRADESH         26
# 225             Jaipur            8       RAJASTHAN         12
#
#      population_total  population_male  population_female  \
# 141          11007835          5871362            5136473
# 185          12478447          6736815            5741632
# 72            8425970          4401299            4024671
# ...

# %% [markdown]
# # e. Calculate the average child sex ratio of the Kerala State.

# %%
df.child_sex_ratio.groupby(df.state_name).mean()["KERALA"]
# Out:
# 957.0

# %% [markdown]
# # 2. PROBLEM

# %% [markdown]
# - Mean = 70 and Standard Deviation = 10.
# - Identify how much area can be found between 70 and 90 with help of Empirical Rule.

# %% [markdown]
# <img src="https://lh3.googleusercontent.com/FsWSVjkkToBCFf9Kdjo8ud_WBeBrVGBeOsjI-PauzmWQFXs1R68uHW1etUa3hZJrnzgu-gf6JgvW_y9R26gtl6Gfl8Kz367rqIQYzkDor2An7M8gtPEYuOyYwEKCHOBP_7Oqoj-q">

# %%
Mean = 70
standard_deviation = 90

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## comparing above image, 90 is 2 standard deviations away from mean =70
# ### required area= 1/2 x (95%) x area under the curve
# ### area under curve=1
# ### required area:

# %%
95/2
# Out:
# 47.5
